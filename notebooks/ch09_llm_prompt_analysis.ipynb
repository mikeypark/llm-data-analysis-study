# %% [markdown]
# # 9장. 회귀 분석으로 숫자 예측하기
#
# 이 파일은 기존 파일명(`ch09_llm_prompt_analysis.ipynb`)과의 호환을 위해 남겨 둔 안내용 노트북입니다.
#
# 현재 9장 강의안은 `book/chapters/ch09_regression_analysis.md`이며, 실습 노트북은 아래 파일로 보강되어 있습니다.
#
# - `notebooks/ch09_regression_analysis.ipynb`
# - `src/regression.py`
# - `scripts/run_regression_analysis.py`
#
# 9장 실습은 `notebooks/ch09_regression_analysis.ipynb`를 열어 진행하세요.

# %% [markdown]
# ## 터미널 실행 방법
#
# 프로젝트 루트에서 아래 명령을 실행하면 9장 회귀 분석 결과가 생성됩니다.
#
# ```bash
# python scripts/preprocess_data.py
# python scripts/run_regression_analysis.py
# ```
